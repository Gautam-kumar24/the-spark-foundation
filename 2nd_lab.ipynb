# %% [markdown]
# <a href="https://colab.research.google.com/github/Gautam-kumar24/the-spark-foundation/blob/main/2nd_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
cv2_imshow(cv2.imread("/content/Screenshot (3).png"))
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7FA94426D9D0>

# %% [markdown]
# # New Section
